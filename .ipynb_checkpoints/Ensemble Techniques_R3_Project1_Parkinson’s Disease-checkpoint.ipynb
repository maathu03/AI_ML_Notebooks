# %%
#Import all the necessary modules
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn import metrics
# %matplotlib inline

# %%
# reading the CSV file into pandas dataframe
parkinsons_df = pd.read_csv("parkinsons_latest.csv")  
parkinsons_df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# 5    phon_R01_S01_6      120.552       131.162       113.787         0.00968
# 6    phon_R01_S02_1      120.267       137.244       114.820         0.00333
# 7    phon_R01_S02_2      107.332       113.840       104.315         0.00290
# 8    phon_R01_S02_3       95.730       132.068        91.754         0.00551
# 9    phon_R01_S02_4       95.056       120.103        91.226         0.00532
# 10   phon_R01_S02_5       88.333       112.240        84.072         0.00505
# ...

# %%
parkinsons_df.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# status                int64
# dtype: object

# %%
parkinsons_df.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'spread1',
#        'spread2', 'D2', 'PPE', 'status'],
#       dtype='object')

# %%
parkinsons_df.shape
# Out:
# (195, 24)

# %%
parkinsons_df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
parkinsons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
# name                195 non-null object
# MDVP:Fo(Hz)         195 non-null float64
# MDVP:Fhi(Hz)        195 non-null float64
# MDVP:Flo(Hz)        195 non-null float64
# MDVP:Jitter(%)      195 non-null float64
# MDVP:Jitter(Abs)    195 non-null float64
# MDVP:RAP            195 non-null float64
# MDVP:PPQ            195 non-null float64
# Jitter:DDP          195 non-null float64
# MDVP:Shimmer        195 non-null float64
# MDVP:Shimmer(dB)    195 non-null float64
# Shimmer:APQ3        195 non-null float64
# Shimmer:APQ5        195 non-null float64
# MDVP:APQ            195 non-null float64
# Shimmer:DDA         195 non-null float64
# NHR                 195 non-null float64
# HNR                 195 non-null float64
# RPDE                195 non-null float64
# DFA                 195 non-null float64
# spread1             195 non-null float64
# ...

# %%
sns.heatmap(parkinsons_df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
parkinsons_df.boxplot()

# %%
#1.USing Pairplots and multivarivate analysis, we can observe that the people with status =1 (who are affected with parkinson disease)
#are not able to modulate their vocal frequency compared to a normal guy and their voice is very broken and jittery.
#2.The Average vocal fundamental frequency-MDVP:Fo(Hz) and MDVP:Fhi(Hz) is low from the below plots.
#3.MDVP:Flo(Hz) and MDVP:Jitter(%) are directly prop.
sns.pairplot(parkinsons_df, hue = "status")

# %%
#1.using Univariate analysis for a patient with parkinsons vs MDVP:Fo(Hz)-Average vocal fundamental frequency
parkinsons_df.plot.scatter(x='status', y='MDVP:Fo(Hz)')

# %%
#2.Status vs MDVP:Fhi(Hz)
parkinsons_df.plot.density(x='status', y='MDVP:Fhi(Hz)')

# %%
# 3.MDVP:Jitter(%) vs status, note the higher jitter range for status of a healthy man.
parkinsons_df.plot.scatter(x='status', y='MDVP:Jitter(%)')

# %%
# 4.MDVP:Jitter(Abs) vs status
parkinsons_df.plot.kde(x='status', y='MDVP:Jitter(Abs)')

# %%
#5.MDVP:RAP vs status
parkinsons_df.plot.scatter(x='status', y='MDVP:RAP')

# %%
parkinsons_df.plot.scatter(x='MDVP:Fo(Hz)', y='Jitter:DDP')

# %%
parkinsons_df.plot.scatter(x='MDVP:Fo(Hz)', y='MDVP:Shimmer')

# %%
parkinsons_df.plot.scatter(x='status', y='MDVP:Shimmer(dB)')

# %%
parkinsons_df.plot.scatter(x='status', y='NHR') 
#we can see that the Tone of the Vowels spelt is very high pitch for non parkinson man.

# %%
parkinsons_df.plot.scatter(x='status', y='HNR')

# %%
sns.heatmap(parkinsons_df.corr(),annot=True,vmin=-1,vmax=1,cmap='seismic')

# %%
#chenckgin the relationship for correlation inbetween the datapoints.
parkinsons_df.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# ...

# %%
#Before creating  X and Y variables, drop the 'name' column for calcualtion purpose,
parkinsons_df['name'] = parkinsons_df['name'].apply(pd.to_numeric, errors='coerce')
parkinsons_df.dtypes
parkinsons_df.drop('name',axis =1,inplace = True)

# %%
# Now build the model
#Q4 Spliting the data set into test and train (70:30)

array = parkinsons_df.values
X = array[:,0:21] # select all rows and first 23 columns which are the attributes
Y = array[:,22]   # select all rows and the 24th column which is the classification "Yes", "No" for parkinsons disease
test_size = 0.30 # taking 70:30 training and test set
seed = 7  # Random numbmer seeding for reapeatability of the code
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
# Create model using entropy

dt_model = DecisionTreeClassifier(criterion = 'entropy' )
dt_model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#Accuracy:

print(dt_model.score(X_test , Y_test))
print(dt_model.score(X_train , Y_train))
# Since the training data is 100% accurate and not the test data, this is a clear case of Overfit model
# Out:
# 0.8813559322033898
# 1.0

# %%
from sklearn import metrics
Y_predict = dt_model.predict(X_test)
print(metrics.confusion_matrix(Y_test, Y_predict))
# Out:
# [[10  2]
#  [ 5 42]]

# %%
reg_dt_model = DecisionTreeClassifier(criterion = 'entropy', max_depth = 18,min_samples_leaf = 5)
reg_dt_model.fit(X_train, Y_train)

Y_predict = reg_dt_model.predict(X_test)

reg_dt_model.score(X_test , Y_test)
# Out:
# 0.8983050847457628

# %%
#Q8 - Random forest , accuracy and optimal no of trees
from sklearn.ensemble import RandomForestClassifier
rfcl = RandomForestClassifier(n_estimators = 999)
rfcl = rfcl.fit(X_train, Y_train)

dt_model.score(X_test , Y_test)
# Out:
# 0.8813559322033898
